# %% [markdown]
# # Amazon Website Services Data Analysis

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# Identity Duplicates, Missing Value, Outliers, Inconsistent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno
import seaborn as sns
import folium

# %%
df_aws_saas = pd.read_csv("../data/raw/SaaS-Sales-fin.csv")

df_aws_saas
# Out:
#       Row ID          Order ID  Order Date  Date Key       Contact Name  \
# 0          1  EMEA-2022-152156   11/9/2022  20221109        Nathan Bell
# 1          2  EMEA-2022-152156   11/9/2022  20221109        Nathan Bell
# 2          3  AMER-2022-138688   6/13/2022  20220613     Deirdre Bailey
# 3          4  EMEA-2021-108966  10/11/2021  20211011         Zoe Hodges
# 4          5  EMEA-2021-108966  10/11/2021  20211011         Zoe Hodges
# ...      ...               ...         ...       ...                ...
# 9989    9990  EMEA-2020-110422   1/22/2020  20200122          Dan Allan
# 9990    9991  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9991    9992  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9992    9993  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9993    9994  AMER-2023-119914    5/5/2023  20230505   Jasmine Springer
#
#             Country           City Region Subregion           Customer  \
# ...

# %%
df_aws_saas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Date Key      9994 non-null   int64
#  4   Contact Name  9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Subregion     9994 non-null   object
#  9   Customer      9994 non-null   object
#  10  Customer ID   9994 non-null   int64
#  11  Industry      9994 non-null   object
#  12  Segment       9994 non-null   object
#  13  Product       9994 non-null   object
#  14  License       9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
# ...

# %% [markdown]
# ### 1. Missing values

# %%
# Checking missing values
df_aws_saas.isnull().sum()
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Date Key        0
# Contact Name    0
# Country         0
# City            0
# Region          0
# Subregion       0
# Customer        0
# Customer ID     0
# Industry        0
# Segment         0
# Product         0
# License         0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Means : tidak ada data yang missing atau yg kurang

# %% [markdown]
# ### 2. Duplicates

# %%
# Checking data duplicates

df_aws_saas.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Means : tidak ada data yg duplikat

# %%
df_aws_saas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Date Key      9994 non-null   int64
#  4   Contact Name  9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Subregion     9994 non-null   object
#  9   Customer      9994 non-null   object
#  10  Customer ID   9994 non-null   int64
#  11  Industry      9994 non-null   object
#  12  Segment       9994 non-null   object
#  13  Product       9994 non-null   object
#  14  License       9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
# ...

# %% [markdown]
# ### 3. Outlier

# %%
# Dicek dulu pake boxplot

plt.figure(figsize=(30,15))

sns.boxplot(data=df_aws_saas, x='Product', y='Profit')

plt.title('Boxplot of Product by Profit')
plt.show()

# %% [markdown]
# Ternyata ada outlier di Produk Big of Database

# %%
# Dicek dulu pake boxplot

plt.figure(figsize=(30,15))

sns.boxplot(data=df_aws_saas, x='Industry', y='Profit')

plt.title('Boxplot of Industry by Profit')
plt.show()

# %%
# Handling outlier

# %%
df_aws_saas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Date Key      9994 non-null   int64
#  4   Contact Name  9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Subregion     9994 non-null   object
#  9   Customer      9994 non-null   object
#  10  Customer ID   9994 non-null   int64
#  11  Industry      9994 non-null   object
#  12  Segment       9994 non-null   object
#  13  Product       9994 non-null   object
#  14  License       9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
# ...

# %% [markdown]
# ### 4. Ubah format date time dan extract ke year

# %%
df_aws_saas['Order Date'] = pd.to_datetime(df_aws_saas['Order Date'])

# %%
# df_aws_saas['Order Year'] = df_aws_saas['Order Date'].dt.year
df_aws_saas.insert(3,'Order Year',df_aws_saas['Order Date'].dt.year)

# %%
df_aws_saas.dtypes
# Out:
# Row ID                   int64
# Order ID                object
# Order Date      datetime64[ns]
# Order Year               int32
# Date Key                 int64
# Contact Name            object
# Country                 object
# City                    object
# Region                  object
# Subregion               object
# Customer                object
# Customer ID              int64
# Industry                object
# Segment                 object
# Product                 object
# License                 object
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# dtype: object

# %%
df_aws_saas
# Out:
#       Row ID          Order ID Order Date  Order Year  Date Key  \
# 0          1  EMEA-2022-152156 2022-11-09        2022  20221109
# 1          2  EMEA-2022-152156 2022-11-09        2022  20221109
# 2          3  AMER-2022-138688 2022-06-13        2022  20220613
# 3          4  EMEA-2021-108966 2021-10-11        2021  20211011
# 4          5  EMEA-2021-108966 2021-10-11        2021  20211011
# ...      ...               ...        ...         ...       ...
# 9989    9990  EMEA-2020-110422 2020-01-22        2020  20200122
# 9990    9991  AMER-2023-121258 2023-02-27        2023  20230227
# 9991    9992  AMER-2023-121258 2023-02-27        2023  20230227
# 9992    9993  AMER-2023-121258 2023-02-27        2023  20230227
# 9993    9994  AMER-2023-119914 2023-05-05        2023  20230505
#
#            Contact Name        Country           City Region Subregion  \
# 0           Nathan Bell        Ireland         Dublin   EMEA      UKIR
# ...

# %% [markdown]
# ### 5. Saving cleaned data

# %%
df_aws_saas.to_csv(r"../data/cleaned/SaaS-Sales-fin-cleaned.csv", index=False)
